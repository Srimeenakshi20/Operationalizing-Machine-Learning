# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.14.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-119981
# aml-quickstarts-119981
# southcentralus
# e8f628b3-bb5b-4edf-947a-8637ca6ea7c2

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'bank-exp-run'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: bank-exp-run,
# Workspace: quick-starts-ws-119981)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "compute-1"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "bank_marketing_data"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [29c9ce78][95b8c98c-b313-48cb-88a3-10f0293eff51], (This step will run and generate new outputs)
# Submitted PipelineRun 3777faf8-2950-4236-9280-adf7e0ab6256
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/bank-exp-run/runs/3777faf8-2950-4236-9280-adf7e0ab6256?wsid=/subscriptions/e8f628b3-bb5b-4edf-947a-8637ca6ea7c2/resourcegroups/aml-quickstarts-119981/workspaces/quick-starts-ws-119981

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: 3777faf8-2950-4236-9280-adf7e0ab6256
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/bank-exp-run/runs/3777faf8-2950-4236-9280-adf7e0ab6256?wsid=/subscriptions/e8f628b3-bb5b-4edf-947a-8637ca6ea7c2/resourcegroups/aml-quickstarts-119981/workspaces/quick-starts-ws-119981
# PipelineRun Status: Running
#
#
# StepRunId: db2a7514-b876-45bd-97b2-b2213080e227
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/bank-exp-run/runs/db2a7514-b876-45bd-97b2-b2213080e227?wsid=/subscriptions/e8f628b3-bb5b-4edf-947a-8637ca6ea7c2/resourcegroups/aml-quickstarts-119981/workspaces/quick-starts-ws-119981
# StepRun( automl_module ) Status: Running
#
# StepRun(automl_module) Execution Summary
# =========================================
# StepRun( automl_module ) Status: Finished
# {'runId': 'db2a7514-b876-45bd-97b2-b2213080e227', 'target': 'compute-1', 'status': 'Completed', 'startTimeUtc': '2020-10-07T13:19:51.146473Z', 'endTimeUtc': '2020-10-07T13:33:23.075252Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '7212064e-56ce-4912-936b-4df1f48a3462', 'StepType': 'AutoMLStep', 'azureml.moduleid': '95b8c98c-b313-48cb-88a3-10f0293eff51', 'azureml.nodeid': '29c9ce78', 'azureml.pipelinerunid': '3777faf8-2950-4236-9280-adf7e0ab6256', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'AUC_weighted', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': None, 'target': 'compute-1', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "e8f628b3-bb5b-4edf-947a-8637ca6ea7c2", "resource_group": "aml-quickstarts-119981", "workspace_name": "quick-starts-ws-119981", "region": "southcentralus", "compute_target": null, "spark_service": null, "azure_service": null, "_local_managed_run_id": null, "many_models": false, "iterations": 1000, "primary_metric": "AUC_weighted", "task_type": "classification", "data_script": null, "validation_size": 0.0, "n_cross_validations": null, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 5, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 20, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["KNN", "BernoulliNaiveBayes", "GradientBoosting", "SVM", "TensorFlowLinearClassifier", "ExtremeRandomTrees", "XGBoostClassifier", "MultinomialNaiveBayes", "LightGBM", "SGD", "TensorFlowDNN", "AveragedPerceptronClassifier", "RandomForest", "LogisticRegression", "DecisionTree", "LinearSVM"], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_DS12_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "metrics": null, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "label_column_name": "y", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true, "scenario": "SDK-1.13.0"}', 'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"592edf93-67ad-40be-b4bc-bbad5878e857\\"}, \\"datasets\\": 0}', 'EnableSubsampling': 'False', 'runTemplate': 'AutoML', 'Orchestrator': 'automl', 'ClientType': 'Others', '_aml_system_scenario_identification': 'Remote.Parent', 'root_attribution': 'azureml.StepRun', 'snapshotId': '7212064e-56ce-4912-936b-4df1f48a3462', 'SetupRunId': 'db2a7514-b876-45bd-97b2-b2213080e227_setup', 'SetupRunContainerId': 'dcid.db2a7514-b876-45bd-97b2-b2213080e227_setup', 'ClientSdkVersion': '1.14.0', 'FeaturizationRunJsonPath': 'featurizer_container.json', 'FeaturizationRunId': 'db2a7514-b876-45bd-97b2-b2213080e227_featurize', 'ProblemInfoJsonString': '{"dataset_num_categorical": 0, "is_sparse": true, "subsampling": false, "dataset_classes": 2, "dataset_features": 132, "dataset_samples": 29655, "single_frequency_class_detected":  ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '3777faf8-2950-4236-9280-adf7e0ab6256', 'status': 'Completed', 'startTimeUtc': '2020-10-07T13:00:26.850909Z', 'endTimeUtc': '2020-10-07T13:37:22.26061Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg119981.blob.core.windows.net/azureml/ExperimentRun/dcid.3777faf8-2950-4236-9280-adf7e0ab6256/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=vHrwAPXNW0XKAXTomtlIn4bK3lFBOEG0mhcZ9XcMlmI%3D&st=2020-10-07T12%3A50%3A39Z&se=2020-10-07T21%3A00%3A39Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg119981.blob.core.windows.net/azureml/ExperimentRun/dcid.3777faf8-2950-4236-9280-adf7e0ab6256/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=28aVR6%2FN%2BNz3%2FFxr3C%2FfJKoJTlcwFWtwK9S3rK97dAQ%3D&st=2020-10-07T12%3A50%3A39Z&se=2020-10-07T21%3A00%3A39Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg119981.blob.core.windows.net/azureml/ExperimentRun/dcid.3777faf8-2950-4236-9280-adf7e0ab6256/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=lpC63eBCgGpV1%2BsHoiriJIdLUYx8y20WdvtUTqd6pKQ%3D&st=2020-10-07T12%3A50%3A39Z&se=2020-10-07T21%3A00%3A39Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/db2a7514-b876-45bd-97b2-b2213080e227/metrics_data
# Downloaded azureml/db2a7514-b876-45bd-97b2-b2213080e227/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  db2a7514-b876-45bd-97b2-b2213080e227_6  \
# weighted_accuracy                                  [0.9770527328284682]
# f1_score_weighted                                  [0.8715233778312342]
# average_precision_score_macro                      [0.7345457155678347]
# balanced_accuracy                                  [0.5843044418140696]
# average_precision_score_micro                      [0.9685883822741614]
# recall_score_micro                                  [0.898937784522003]
# accuracy                                            [0.898937784522003]
# AUC_weighted                                       [0.8998845969320939]
# matthews_correlation                               [0.3161462686094845]
# recall_score_macro                                 [0.5843044418140696]
# AUC_macro                                          [0.8998845969320937]
# precision_score_macro                              [0.7963914504532666]
# average_precision_score_weighted                   [0.9297184273054386]
# f1_score_micro                                     [0.8989377845220029]
# log_loss                                          [0.24445814271178049]
# norm_macro_recall                                  [0.1686088836281392]
# recall_score_weighted                               [0.898937784522003]
# precision_score_micro                               [0.898937784522003]
# AUC_micro                                          [0.9679270334184549]
# f1_score_macro                                       [0.61475181040158]
# precision_score_weighted                           [0.8808938598034951]
#
#                                  db2a7514-b876-45bd-97b2-b2213080e227_13  \
# weighted_accuracy                                   [0.7759553543106018]
# f1_score_weighted                                   [0.8096680091565209]
# average_precision_score_macro                       [0.7104144598322196]
# balanced_accuracy                                    [0.759517048348884]
# average_precision_score_micro                       [0.8171540343452061]
# recall_score_micro                                  [0.7726858877086494]
# accuracy                                            [0.7726858877086494]
# AUC_weighted                                        [0.8453455330862263]
# matthews_correlation                                 [0.363892509182092]
# recall_score_macro                                   [0.759517048348884]
# AUC_macro                                           [0.8453455330862263]
# precision_score_macro                               [0.6275617142316041]
# average_precision_score_weighted                    [0.9161376474856926]
# f1_score_micro                                      [0.7726858877086495]
# log_loss                                             [0.588962453704774]
# norm_macro_recall                                    [0.519034096697768]
# recall_score_weighted                               [0.7726858877086494]
# precision_score_micro                               [0.7726858877086494]
# AUC_micro                                            [0.834344675452069]
# f1_score_macro                                      [0.6405029205300319]
# precision_score_weighted                            [0.8854369828770557]
#
#                                  db2a7514-b876-45bd-97b2-b2213080e227_19  \
# weighted_accuracy                                   [0.9843450583187134]
# f1_score_weighted                                   [0.8353395018439429]
# average_precision_score_macro                       [0.7021889413428057]
# balanced_accuracy                                                  [0.5]
# average_precision_score_micro                       [0.9600145182669032]
# recall_score_micro                                  [0.8880121396054628]
# accuracy                                            [0.8880121396054628]
# AUC_weighted                                        [0.8569113100563678]
# matthews_correlation                                               [0.0]
# recall_score_macro                                                 [0.5]
# AUC_macro                                           [0.8569113100563679]
# precision_score_macro                               [0.4440060698027314]
# average_precision_score_weighted                    [0.9171820809823562]
# f1_score_micro                                      [0.8880121396054628]
# log_loss                                           [0.28147117514824194]
# norm_macro_recall                                                  [0.0]
# recall_score_weighted                               [0.8880121396054628]
# precision_score_micro                               [0.8880121396054628]
# AUC_micro                                           [0.9589993575588156]
# f1_score_macro                                      [0.4703423886834914]
# precision_score_weighted                             [0.788565560086672]
#
#                                  db2a7514-b876-45bd-97b2-b2213080e227_3  \
# weighted_accuracy                                  [0.8324088485182813]
# f1_score_weighted                                  [0.8619320901855936]
# average_precision_score_macro                      [0.7578492589293324]
# balanced_accuracy                                  [0.8601997417786891]
# average_precision_score_micro                      [0.8632832015883133]
# recall_score_micro                                 [0.8379362670713202]
# accuracy                                           [0.8379362670713202]
# AUC_weighted                                       [0.9196225967727892]
# matthews_correlation                               [0.5252333699559488]
# recall_score_macro                                 [0.8601997417786891]
# AUC_macro                                          [0.9196225967727893]
# precision_score_macro                              [0.6914702184078607]
# average_precision_score_weighted                    [0.937377187018323]
# f1_score_micro                                     [0.8379362670713202]
# log_loss                                          [0.42514461499970674]
# norm_macro_recall                                  [0.7203994835573782]
# recall_score_weighted                              [0.8379362670713202]
# precision_score_micro                              [0.8379362670713202]
# AUC_micro                                          [0.8918876948335295]
# f1_score_macro                                     [0.7261858076563958]
# precision_score_weighted                           [0.9180362719060251]
#
#                                  db2a7514-b876-45bd-97b2-b2213080e227_8  \
# weighted_accuracy                                  [0.9803684609969352]
# f1_score_weighted                                  [0.8644108754585085]
# average_precision_score_macro                      [0.7473478352709342]
# balanced_accuracy                                  [0.5633197924597154]
# average_precision_score_micro                      [0.9695722445824287]
# recall_score_micro                                 [0.8974203338391502]
# accuracy                                           [0.8974203338391502]
# AUC_weighted                                       [0.9032096130940805]
# matthews_correlation                              [0.28295388288069445]
# recall_score_macro                                 [0.5633197924597154]
# AUC_macro                                          [0.9032096130940803]
# precision_score_macro                                [0.81610534687159]
# average_precision_score_weighted                   [0.9329675379413778]
# f1_score_micro                                     [0.8974203338391502]
# log_loss                                           [0.2525223977602736]
# norm_macro_recall                                 [0.12663958491943084]
# recall_score_weighted                              [0.8974203338391502]
# precision_score_micro                              [0.8974203338391502]
# AUC_micro                                          [0.9685237898964036]
# f1_score_macro                                     [0.5849235076462538]
# precision_score_weighted                           [0.8818827659402554]
#
#                                  db2a7514-b876-45bd-97b2-b2213080e227_7  \
# weighted_accuracy                                  [0.9628988885142022]
# f1_score_weighted                                  [0.8840204983464784]
# average_precision_score_macro                       [0.756933822416205]
# balanced_accuracy                                  [0.6397877546786404]
# average_precision_score_micro                      [0.9669930483276719]
# recall_score_micro                                 [0.8986342943854325]
# accuracy                                           [0.8986342943854325]
# AUC_weighted                                       [0.9209535294259301]
# matthews_correlation                               [0.3772870761781996]
# recall_score_macro                                 [0.6397877546786404]
# AUC_macro                                            [0.92095352942593]
# precision_score_macro                              [0.7545744049225455]
# average_precision_score_weighted                   [0.9374091731290267]
# f1_score_micro                                     [0.8986342943854325]
# log_loss                                           [0.2294777713300157]
# norm_macro_recall                                  [0.2795755093572807]
# recall_score_weighted                              [0.8986342943854325]
# precision_score_micro                              [0.8986342943854325]
# AUC_micro                                           [0.969459036890861]
# f1_score_macro                                     [0.6740908552475717]
# precision_score_weighted                           [0.8810286230332911]
#
#                                  db2a7514-b876-45bd-97b2-b2213080e227_28  \
# weighted_accuracy                                   [0.6992955672902882]
# f1_score_weighted                                   [0.7572254775991746]
# average_precision_score_macro                       [0.7179342793124167]
# balanced_accuracy                                   [0.7219110229379806]
# average_precision_score_micro                       [0.8383541147158755]
# recall_score_micro                                   [0.703793626707132]
# accuracy                                             [0.703793626707132]
# AUC_weighted                                        [0.8432787437922227]
# matthews_correlation                               [0.29321668881002766]
# recall_score_macro                                  [0.7219110229379806]
# AUC_macro                                           [0.8432787437922227]
# precision_score_macro                               [0.5968586704914891]
# average_precision_score_weighted                     [0.919009971546107]
# f1_score_micro                                       [0.703793626707132]
# log_loss                                            [0.5891544648611761]
# norm_macro_recall                                   [0.4438220458759612]
# recall_score_weighted                                [0.703793626707132]
# precision_score_micro                                [0.703793626707132]
# AUC_micro                                           [0.8579365894432407]
# f1_score_macro                                      [0.5838431898695389]
# precision_score_weighted                            [0.8755871955102443]
#
#                                  db2a7514-b876-45bd-97b2-b2213080e227_34  \
# weighted_accuracy                                   [0.8426225421916322]
# f1_score_weighted                                    [0.865639785413692]
# average_precision_score_macro                       [0.7486839588372426]
# balanced_accuracy                                   [0.8480527816214594]
# average_precision_score_micro                       [0.8736729658547723]
# recall_score_micro                                  [0.8437025796661608]
# accuracy                                            [0.8437025796661608]
# AUC_weighted                                         [0.919867110496122]
# matthews_correlation                                [0.5173452955772554]
# recall_score_macro                                  [0.8480527816214594]
# AUC_macro                                            [0.919867110496122]
# precision_score_macro                               [0.6922453784229546]
# average_precision_score_weighted                    [0.9355898218607201]
# f1_score_micro                                      [0.8437025796661607]
# log_loss                                            [0.4153249433702014]
# norm_macro_recall                                   [0.6961055632429187]
# recall_score_weighted                               [0.8437025796661608]
# precision_score_micro                               [0.8437025796661608]
# AUC_micro                                           [0.9041465779069314]
# f1_score_macro                                      [0.7278180775600387]
# precision_score_weighted                            [0.9144347436431947]
#
#                                  db2a7514-b876-45bd-97b2-b2213080e227_38  \
# weighted_accuracy                                   [0.9551034378647902]
# f1_score_weighted                                   [0.9055861909989514]
# average_precision_score_macro                       [0.8185147125711998]
# balanced_accuracy                                   [0.7291704871935937]
# average_precision_score_micro                       [0.9807111812789772]
# recall_score_micro                                  [0.9101669195751139]
# accuracy                                            [0.9101669195751139]
# AUC_weighted                                        [0.9448686387068929]
# matthews_correlation                                [0.5078083917783154]
# recall_score_macro                                  [0.7291704871935937]
# AUC_macro                                           [0.9448686387068929]
# precision_score_macro                               [0.7813073423178631]
# average_precision_score_weighted                    [0.9538951198454642]
# f1_score_micro                                      [0.9101669195751139]
# log_loss                                           [0.18281463530189265]
# norm_macro_recall                                  [0.45834097438718735]
# recall_score_weighted                               [0.9101669195751139]
# precision_score_micro                               [0.9101669195751139]
# AUC_micro                                           [0.9797653592950187]
# f1_score_macro                                      [0.7514687835088534]
# precision_score_weighted                            [0.9029367033539614]
#
#                                  db2a7514-b876-45bd-97b2-b2213080e227_39  ...  \
# weighted_accuracy                                   [0.9567430786085922]  ...
# f1_score_weighted                                   [0.9064544844068773]  ...
# average_precision_score_macro                       [0.8149797138116006]  ...
# balanced_accuracy                                   [0.7286698823926039]  ...
# average_precision_score_micro                       [0.9800202358832737]  ...
# recall_score_micro                                  [0.9113808801213961]  ...
# accuracy                                            [0.9113808801213961]  ...
# AUC_weighted                                         [0.942698579412315]  ...
# matthews_correlation                                [0.5114573730922357]  ...
# recall_score_macro                                  [0.7286698823926039]  ...
# AUC_macro                                           [0.9426985794123149]  ...
# precision_score_macro                               [0.7859893941359626]  ...
# average_precision_score_weighted                    [0.9528452834792758]  ...
# f1_score_micro                                      [0.9113808801213961]  ...
# log_loss                                           [0.20208135218749296]  ...
# norm_macro_recall                                  [0.45733976478520777]  ...
# recall_score_weighted                               [0.9113808801213961]  ...
# precision_score_micro                               [0.9113808801213961]  ...
# AUC_micro                                            [0.979061114808154]  ...
# f1_score_macro                                      [0.7528350473090171]  ...
# precision_score_weighted                            [0.9038232896393633]  ...
#
#                                  db2a7514-b876-45bd-97b2-b2213080e227_25  \
# weighted_accuracy                                   [0.9816173059418324]
# f1_score_weighted                                   [0.8443705706533633]
# average_precision_score_macro                       [0.7588134094336991]
# balanced_accuracy                                   [0.5186163857537414]
# average_precision_score_micro                       [0.9726637025734595]
# recall_score_micro                                  [0.8895295902883156]
# accuracy                                            [0.8895295902883156]
# AUC_weighted                                        [0.9180948490961327]
# matthews_correlation                                [0.1353106026888131]
# recall_score_macro                                  [0.5186163857537414]
# AUC_macro                                           [0.9180948490961328]
# precision_score_macro                               [0.7458715596330275]
# average_precision_score_weighted                    [0.9376738693793926]
# f1_score_micro                                      [0.8895295902883156]
# log_loss                                           [0.23592302405601606]
# norm_macro_recall                                  [0.03723277150748272]
# recall_score_weighted                               [0.8895295902883156]
# precision_score_micro                               [0.8895295902883156]
# AUC_micro                                           [0.9712025163431051]
# f1_score_macro                                       [0.508697276448208]
# precision_score_weighted                            [0.8590714315546213]
#
#                                  db2a7514-b876-45bd-97b2-b2213080e227_26  \
# weighted_accuracy                                   [0.9588708979231947]
# f1_score_weighted                                   [0.8910657230822897]
# average_precision_score_macro                        [0.762916915752683]
# balanced_accuracy                                   [0.6697448536344557]
# average_precision_score_micro                       [0.9678452620136797]
# recall_score_micro                                  [0.9013657056145675]
# accuracy                                            [0.9013657056145675]
# AUC_weighted                                         [0.922078848266268]
# matthews_correlation                                [0.4201436444414131]
# recall_score_macro                                  [0.6697448536344557]
# AUC_macro                                           [0.9220788482662681]
# precision_score_macro                                [0.759979431165331]
# average_precision_score_weighted                    [0.9387247559318522]
# f1_score_micro                                      [0.9013657056145675]
# log_loss                                           [0.22559665809866133]
# norm_macro_recall                                  [0.33948970726891137]
# recall_score_weighted                               [0.9013657056145675]
# precision_score_micro                               [0.9013657056145675]
# AUC_micro                                           [0.9699062127977047]
# f1_score_macro                                      [0.7015905048446347]
# precision_score_weighted                            [0.8875013725292455]
#
#                                  db2a7514-b876-45bd-97b2-b2213080e227_2  \
# weighted_accuracy                                  [0.9843450583187134]
# f1_score_weighted                                  [0.8353395018439429]
# average_precision_score_macro                      [0.7334201091205874]
# balanced_accuracy                                                 [0.5]
# average_precision_score_micro                      [0.9649341522582032]
# recall_score_micro                                 [0.8880121396054628]
# accuracy                                           [0.8880121396054628]
# AUC_weighted                                       [0.8931025827688215]
# matthews_correlation                                              [0.0]
# recall_score_macro                                                [0.5]
# AUC_macro                                          [0.8931025827688215]
# precision_score_macro                              [0.4440060698027314]
# average_precision_score_weighted                    [0.926460407260367]
# f1_score_micro                                     [0.8880121396054628]
# log_loss                                           [0.2482391772313256]
# norm_macro_recall                                                 [0.0]
# recall_score_weighted                              [0.8880121396054628]
# precision_score_micro                              [0.8880121396054628]
# AUC_micro                                          [0.9661975541181862]
# f1_score_macro                                     [0.4703423886834914]
# precision_score_weighted                            [0.788565560086672]
#
#                                  db2a7514-b876-45bd-97b2-b2213080e227_15  \
# weighted_accuracy                                   [0.9787347988884799]
# f1_score_weighted                                   [0.8726326181830822]
# average_precision_score_macro                       [0.7556417256267032]
# balanced_accuracy                                   [0.5851588505632151]
# average_precision_score_micro                       [0.9724232411039149]
# recall_score_micro                                  [0.9004552352048558]
# accuracy                                            [0.9004552352048558]
# AUC_weighted                                        [0.9154112183637216]
# matthews_correlation                                [0.3277503624684955]
# recall_score_macro                                  [0.5851588505632151]
# AUC_macro                                           [0.9154112183637215]
# precision_score_macro                               [0.8153527184426062]
# average_precision_score_weighted                    [0.9366889049245126]
# f1_score_micro                                      [0.9004552352048558]
# log_loss                                           [0.22219284968070052]
# norm_macro_recall                                   [0.1703177011264303]
# recall_score_weighted                               [0.9004552352048558]
# precision_score_micro                               [0.9004552352048558]
# AUC_micro                                           [0.9710027378586675]
# f1_score_macro                                      [0.6167245903964821]
# precision_score_weighted                            [0.8852554281634775]
#
#                                  db2a7514-b876-45bd-97b2-b2213080e227_11  \
# weighted_accuracy                                   [0.8108389669515985]
# f1_score_weighted                                   [0.8487988518784831]
# average_precision_score_macro                       [0.7574948028326628]
# balanced_accuracy                                   [0.8585775228907451]
# average_precision_score_micro                       [0.8636332017369978]
# recall_score_micro                                  [0.8203338391502276]
# accuracy                                            [0.8203338391502276]
# AUC_weighted                                        [0.9222413943209834]
# matthews_correlation                                [0.5088047667771256]
# recall_score_macro                                  [0.8585775228907451]
# AUC_macro                                           [0.9222413943209835]
# precision_score_macro                               [0.6804925533313504]
# average_precision_score_weighted                    [0.9374976103789048]
# f1_score_micro                                      [0.8203338391502276]
# log_loss                                               [1.0633844077008]
# norm_macro_recall                                   [0.7171550457814901]
# recall_score_weighted                               [0.8203338391502276]
# precision_score_micro                               [0.8203338391502276]
# AUC_micro                                            [0.884417047948218]
# f1_score_macro                                       [0.709896108469801]
# precision_score_weighted                            [0.9174535658156904]
#
#                                  db2a7514-b876-45bd-97b2-b2213080e227_0  \
# weighted_accuracy                                  [0.9514937218005303]
# f1_score_weighted                                  [0.9091539479147899]
# average_precision_score_macro                      [0.8151093723721079]
# balanced_accuracy                                  [0.7513392683482543]
# average_precision_score_micro                      [0.9806603102489483]
# recall_score_micro                                 [0.9116843702579667]
# accuracy                                           [0.9116843702579667]
# AUC_weighted                                       [0.9450464668693167]
# matthews_correlation                               [0.5323740218566827]
# recall_score_macro                                 [0.7513392683482543]
# AUC_macro                                          [0.9450464668693166]
# precision_score_macro                              [0.7819118765348991]
# average_precision_score_weighted                   [0.9531771295804466]
# f1_score_micro                                     [0.9116843702579667]
# log_loss                                          [0.17775706110025447]
# norm_macro_recall                                  [0.5026785366965085]
# recall_score_weighted                              [0.9116843702579667]
# precision_score_micro                              [0.9116843702579667]
# AUC_micro                                           [0.979695082216353]
# f1_score_macro                                     [0.7653697272147331]
# precision_score_weighted                           [0.9072720074188747]
#
#                                  db2a7514-b876-45bd-97b2-b2213080e227_12  \
# weighted_accuracy                                   [0.9733581661317896]
# f1_score_weighted                                    [0.877118772382446]
# average_precision_score_macro                         [0.76877243670514]
# balanced_accuracy                                   [0.6037631958684591]
# average_precision_score_micro                       [0.9722877075789483]
# recall_score_micro                                  [0.8998482549317147]
# accuracy                                            [0.8998482549317147]
# AUC_weighted                                        [0.9157140819528496]
# matthews_correlation                                [0.3425618863319073]
# recall_score_macro                                  [0.6037631958684591]
# AUC_macro                                           [0.9157140819528495]
# precision_score_macro                               [0.7827318611987382]
# average_precision_score_weighted                    [0.9391333601726443]
# f1_score_micro                                      [0.8998482549317147]
# log_loss                                            [0.2391674740508447]
# norm_macro_recall                                  [0.20752639173691811]
# recall_score_weighted                               [0.8998482549317147]
# precision_score_micro                               [0.8998482549317147]
# AUC_micro                                            [0.971751009139244]
# f1_score_macro                                      [0.6389249737001499]
# precision_score_weighted                             [0.881078862438548]
#
#                                  db2a7514-b876-45bd-97b2-b2213080e227_17  \
# weighted_accuracy                                   [0.9657569061573852]
# f1_score_weighted                                   [0.8842973142933791]
# average_precision_score_macro                       [0.7457518193109824]
# balanced_accuracy                                   [0.6359056362265605]
# average_precision_score_micro                       [0.9691083435987582]
# recall_score_micro                                  [0.9001517450682853]
# accuracy                                            [0.9001517450682853]
# AUC_weighted                                        [0.8997197354065134]
# matthews_correlation                                [0.3791747467254539]
# recall_score_macro                                  [0.6359056362265605]
# AUC_macro                                           [0.8997197354065133]
# precision_score_macro                               [0.7644730059514154]
# average_precision_score_weighted                    [0.9321923090198803]
# f1_score_micro                                      [0.9001517450682853]
# log_loss                                            [0.2360036630530646]
# norm_macro_recall                                    [0.271811272453121]
# recall_score_weighted                               [0.9001517450682853]
# precision_score_micro                               [0.9001517450682853]
# AUC_micro                                           [0.9680828772154434]
# f1_score_macro                                      [0.6720471598879572]
# precision_score_weighted                            [0.8825167405284267]
#
#                                  db2a7514-b876-45bd-97b2-b2213080e227_22  \
# weighted_accuracy                                   [0.7733034846131197]
# f1_score_weighted                                   [0.8061104018510354]
# average_precision_score_macro                        [0.714607085448697]
# balanced_accuracy                                   [0.7488357812491317]
# average_precision_score_micro                       [0.8032965287624728]
# recall_score_micro                                  [0.7684370257966616]
# accuracy                                            [0.7684370257966616]
# AUC_weighted                                        [0.8192798144659508]
# matthews_correlation                                [0.3489153309546805]
# recall_score_macro                                  [0.7488357812491317]
# AUC_macro                                           [0.8192798144659506]
# precision_score_macro                               [0.6223114975307024]
# average_precision_score_weighted                    [0.9107569857848307]
# f1_score_micro                                      [0.7684370257966616]
# log_loss                                            [0.5622062193467914]
# norm_macro_recall                                   [0.4976715624982635]
# recall_score_weighted                               [0.7684370257966616]
# precision_score_micro                               [0.7684370257966616]
# AUC_micro                                           [0.8350564726524992]
# f1_score_macro                                       [0.633783348951154]
# precision_score_weighted                            [0.8819661019615973]
#
#                                  db2a7514-b876-45bd-97b2-b2213080e227_31
# weighted_accuracy                                   [0.9518725603287422]
# f1_score_weighted                                   [0.9097783194067844]
# average_precision_score_macro                       [0.8186104139180449]
# balanced_accuracy                                   [0.7528651636482189]
# average_precision_score_micro                       [0.9799438059930927]
# recall_score_micro                                  [0.9122913505311078]
# accuracy                                            [0.9122913505311078]
# AUC_weighted                                        [0.9418659360892994]
# matthews_correlation                                [0.5356060954722102]
# recall_score_macro                                  [0.7528651636482189]
# AUC_macro                                           [0.9418659360892994]
# precision_score_macro                               [0.7836233799153131]
# average_precision_score_weighted                    [0.9535604080734286]
# f1_score_micro                                      [0.9122913505311078]
# log_loss                                           [0.18420822105258325]
# norm_macro_recall                                   [0.5057303272964377]
# recall_score_weighted                               [0.9122913505311078]
# precision_score_micro                               [0.9122913505311078]
# AUC_micro                                            [0.978978679702773]
# f1_score_macro                                      [0.7669823064091336]
# precision_score_weighted                            [0.9079165423122104]
#
# [21 rows x 36 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/db2a7514-b876-45bd-97b2-b2213080e227/model_data
# Downloaded azureml/db2a7514-b876-45bd-97b2-b2213080e227/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                      importance_type='split',
#                                                                      learning_rate=0.1,
#                                                                      max_depth=-1,
#                                                                      min_child_samples=20,
#                                                                      min_child_weight=0.001,
#                                                                      min_split_gain=0.0,
#                                                                      n_estimators=100,
#                                                                      n_jobs=1,
#                                                                      num_leaves=31,
#                                                                      objective=None,
#                                                                      random_state=None,
#                                                                      reg_alpha=0.0,
#                                                                      reg_lambda=0.0,
#                                                                      silent=True,
#                                                                      subsample=1.0,
#                                                                      subsample_for_bin=200000,
#                                                                      subsample_freq=0,
#                                                                      verbose=-10))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('MaxAbsScaler', MaxAbsScaler(copy=True)),
#  ('LightGBMClassifier',
#   LightGBMClassifier(boosting_type='gbdt', class_weight=None,
#                      colsample_bytree=1.0, importance_type='split',
#                      learning_rate=0.1, max_depth=-1, min_child_samples=20,
#                      min_child_weight=0.001, min_split_gain=0.0, n_estimators=100,
#                      n_jobs=1, num_leaves=31, objective=None, random_state=None,
#                      reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=1.0,
#                      subsample_for_bin=200000, subsample_freq=0, verbose=-10))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_982ca24c_08a2_11eb_aae9_000d3aeb3bcdrow0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_982ca24c_08a2_11eb_aae9_000d3aeb3bcdrow0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_982ca24c_08a2_11eb_aae9_000d3aeb3bcdrow1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_982ca24c_08a2_11eb_aae9_000d3aeb3bcdrow1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_982ca24c_08a2_11eb_aae9_000d3aeb3bcd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_982ca24c_08a2_11eb_aae9_000d3aeb3bcdlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_982ca24c_08a2_11eb_aae9_000d3aeb3bcdrow0_col0" class="data row0 col0" >28431</td>
#                         <td id="T_982ca24c_08a2_11eb_aae9_000d3aeb3bcdrow0_col1" class="data row0 col1" >827</td>
#             </tr>
#             <tr>
#                         <th id="T_982ca24c_08a2_11eb_aae9_000d3aeb3bcdlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_982ca24c_08a2_11eb_aae9_000d3aeb3bcdrow1_col0" class="data row1 col0" >1246</td>
#                         <td id="T_982ca24c_08a2_11eb_aae9_000d3aeb3bcdrow1_col1" class="data row1 col1" >2446</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: 73166e33-4193-4344-9a89-d71ace722f51,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/e8f628b3-bb5b-4edf-947a-8637ca6ea7c2/resourceGroups/aml-quickstarts-119981/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-119981/PipelineRuns/PipelineSubmit/73166e33-4193-4344-9a89-d71ace722f51)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  08cb3d7f-d1d4-4b60-a036-d94f8ae9d947

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
